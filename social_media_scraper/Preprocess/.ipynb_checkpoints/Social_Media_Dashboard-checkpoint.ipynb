# %% [markdown]
# # Youtube Preprocessing

# %%
import pandas as pd
from datetime import datetime, timedelta
import re

# %%
df = pd.read_excel('../Scraping_Output/facebook_data.csv')
df
# Out:
#             user_id  platform                               post_id  date  \
# 0  aljazeerachannel  Facebook  27c8d322-f361-48cc-bf5b-a886062806f0   NaN
#
#    likes  comments  shares                                          post_text  \
# 0    356        64      12  Breaking | Reuters on diplomats: #Washington a...
#
#                                     post_origin_text         date_scraped  \
# 0  Al Jazeera Channel - قناة الجزيرة\n n\nd\no\ne...  2025-03-09 22:18:20
#
#    views      followers  country content_type  sentiment_score
# 0    NaN  30M followers      NaN        image              NaN

# %%
# Remove empty rows where post_origin_text is empty
df = df.dropna(subset=['post_origin_text'])

# Reset the index after dropping rows
df = df.reset_index(drop=True)

df.head(2)
# Out:
#             user_id  platform                               post_id  date  \
# 0  aljazeerachannel  Facebook  27c8d322-f361-48cc-bf5b-a886062806f0   NaN
#
#    likes  comments  shares                                          post_text  \
# 0    356        64      12  Breaking | Reuters on diplomats: #Washington a...
#
#                                     post_origin_text         date_scraped  \
# 0  Al Jazeera Channel - قناة الجزيرة\n n\nd\no\ne...  2025-03-09 22:18:20
#
#    views      followers  country content_type  sentiment_score
# 0    NaN  30M followers      NaN        image              NaN

# %%
unique_dates = df['date'].unique()
print(unique_dates)
# Out:
# [nan]

# %%
# Function to extract time (e.g., '6h')
def extract_time(post_text):
    # Matching time formats like '6h', '5d', '2m', '1y'
    match = re.search(r'(\d+)(h|d|m|y)', post_text)
    return match.group(0) if match else None

# Applying the function to the 'post_text' column and creating a new column 'time'
df['date_difference'] = df['post_origin_text'].apply(extract_time)


# Remove empty rows where post_origin_text is empty
df = df.dropna(subset=['date_difference'])

# Reset the index after dropping rows
df = df.reset_index(drop=True)


df.head(2)
# Out:
#             user_id  platform                               post_id  date  \
# 0  aljazeerachannel  Facebook  27c8d322-f361-48cc-bf5b-a886062806f0   NaN
#
#    likes  comments  shares                                          post_text  \
# 0    356        64      12  Breaking | Reuters on diplomats: #Washington a...
#
#                                     post_origin_text         date_scraped  \
# 0  Al Jazeera Channel - قناة الجزيرة\n n\nd\no\ne...  2025-03-09 22:18:20
#
#    views      followers  country content_type  sentiment_score date_difference
# 0    NaN  30M followers      NaN        image              NaN              1m

# %%
unique_dates = df['date_difference'].unique()
print(unique_dates)
# Out:
# ['1m']

# %%
# Function to calculate post date
def get_post_date(relative_time, scrape_date):
    match = re.match(r"(\d+)(m|h|d|y)", relative_time)
    if match:
        value, unit = int(match.group(1)), match.group(2)
        if unit == "m":
            return scrape_date - timedelta(minutes=value)
        elif unit == "h":
            return scrape_date - timedelta(hours=value)
        elif unit == "f":
            return scrape_date - timedelta(days=value)
        elif unit == "y":
            return scrape_date.replace(year=scrape_date.year - value)

    return None

# %%
# Apply function to DataFrame
df['date_scraped'] = pd.to_datetime(df['date_scraped'])
df['date'] = df.apply(lambda row: get_post_date(row['date_difference'], row['date_scraped']), axis=1)
# Print results
df
# Out:
#             user_id  platform                               post_id  \
# 0  aljazeerachannel  Facebook  27c8d322-f361-48cc-bf5b-a886062806f0
#
#                  date  likes  comments  shares  \
# 0 2025-03-09 22:17:20    356        64      12
#
#                                            post_text  \
# 0  Breaking | Reuters on diplomats: #Washington a...
#
#                                     post_origin_text        date_scraped  \
# 0  Al Jazeera Channel - قناة الجزيرة\n n\nd\no\ne... 2025-03-09 22:18:20
#
#    views      followers  country content_type  sentiment_score date_difference
# 0    NaN  30M followers      NaN        image              NaN              1m

# %%
unique_likes = df['likes'].unique()
print(unique_likes)
# Out:
# [356]

# %%
# Function to convert likes count to integer
def parse_likes_comments_shares_views_followers(values):
    values = str(values).replace(" ", "")  # Remove all spaces   
    match = re.match(r"(\d+(\.\d+)?)([KM]?)", values)
    if match:
        value, suffix = float(match.group(1)), match.group(3)
        if suffix == "K":
            return int(value * 1_000)
        elif suffix == "M":
            return int(value * 1_000_000)
        return int(value)
    return 0

# %%
# Apply the function to the 'Likes' column
df['likes'] = df['likes'].apply(parse_likes_comments_shares_views_followers)
df
# Out:
#               user_id  platform                               post_id  \
# 0    aljazeerachannel  Facebook  c83048a0-3b7e-4ac1-9dd8-35be5a6ecfab
# 1    aljazeerachannel  Facebook  69e34b53-c500-4eff-8d4a-f3c208b4b79b
# 2    aljazeerachannel  Facebook  03d3f92a-da56-4320-bd08-a64f3cf38c0e
# 3    aljazeerachannel  Facebook  6f000c7c-47eb-4349-bfa8-4a17e74f8404
# 4    aljazeerachannel  Facebook  9d32629d-adc1-4bb5-937e-7797a1bbe47e
# ..                ...       ...                                   ...
# 253  aljazeerachannel  Facebook  b182c81d-ab85-48fd-b728-3677d8d1e99b
# 254  aljazeerachannel  Facebook  76e04484-13c8-4cb8-a114-1b4befc0bc9e
# 255  aljazeerachannel  Facebook  52a203ef-40ca-440c-b916-da85e6775c44
# 256  aljazeerachannel  Facebook  be830853-40df-4b05-b272-883bdd578dff
# 257  aljazeerachannel  Facebook  4b621827-8143-40c8-bc0c-b3f969e9ea79
#
#                    date  likes comments shares  views followers  country  \
# 0   2025-03-06 17:45:07    406       55     18    NaN      20 M      NaN
# 1   2025-03-06 17:39:38   5900      927     87    NaN      20 M      NaN
# 2   2025-03-06 17:40:02    151      NaN    NaN    NaN       NaN      NaN
# 3   2025-03-06 17:45:15    767       28     48    NaN       NaN      NaN
# 4   2025-03-06 17:52:43    317       21      3    NaN       NaN      NaN
# ..                  ...    ...      ...    ...    ...       ...      ...
# 253 2024-03-06 19:39:37   3500       33     53    NaN       NaN      NaN
# 254 2024-03-06 19:39:47    220        8      6    NaN       NaN      NaN
# 255 2024-03-06 19:39:57    230       11      6    NaN       NaN      NaN
# 256 2024-03-06 19:40:08    259       15      4    NaN       NaN      NaN
# 257 2024-03-06 19:40:19    274       63      4    NaN       NaN      NaN
#
#     content_type  sentiment_score  \
# 0          video              NaN
# 1          video              NaN
# 2          video              NaN
# 3          video              NaN
# 4          video              NaN
# ..           ...              ...
# 253        video              NaN
# 254        image              NaN
# 255        video              NaN
# 256        video              NaN
# 257        video              NaN
#
#                                              post_text  \
# 0    A Palestinian mother's shock, the moment she r...
# 1    Live on the air.. Violent clashes between the ...
# 2    #FIFA announces a unique offer in the final #F...
# 3    “With Palestinian and decorations”.. Children ...
# 4    Is there a common Qasim between Netanyahu and ...
# ..                                                 ...
# 253  مخاوف من عواقب “خطيرة وبعيدة المدى” إثر استهدا...
# 254     حرب العملات الرقمية المشفرة بين #حماس وإسرائيل
# 255  تفاعل على منصات التواصل مع كشف شركة “آبل” عن ن...
# 256  الاتحاد الدولي للنقل الجوي يتوقع عودة شركات ال...
# 257  رضا الجزائري وكتب الأرصفة.. حكاية تروي ظمأ الق...
#
#                                       post_origin_text        date_scraped  \
# 0    Al Jazeera Channel - قناة الجزيرة \nS\nd\ne\nn... 2025-03-06 18:39:07
# 1    Al Jazeera Channel - قناة الجزيرة \no\ns\nr\nS... 2025-03-06 18:39:38
# 2    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:02
# 3    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:15
# 4    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:41:43
# ..                                                 ...                 ...
# 253  Al Jazeera Channel - قناة الجزيرة \np\nd\ns\nS... 2025-03-06 19:39:37
# 254  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:47
# 255  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:57
# 256  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:40:08
# 257  Al Jazeera Channel - قناة الجزيرة \ne\nn\np\nr... 2025-03-06 19:40:19
#
#     date_difference
# 0               54m
# 1                1h
# 2                1h
# 3               55m
# 4               49m
# ..              ...
# 253              1y
# 254              1y
# 255              1y
# 256              1y
# 257              1y
#
# [258 rows x 16 columns]

# %%
df['comments'] = df['comments'].fillna(0)

df['comments'] = df['comments'].apply(parse_likes_comments_shares_views_followers)

df
# Out:
#               user_id  platform                               post_id  \
# 0    aljazeerachannel  Facebook  c83048a0-3b7e-4ac1-9dd8-35be5a6ecfab
# 1    aljazeerachannel  Facebook  69e34b53-c500-4eff-8d4a-f3c208b4b79b
# 2    aljazeerachannel  Facebook  03d3f92a-da56-4320-bd08-a64f3cf38c0e
# 3    aljazeerachannel  Facebook  6f000c7c-47eb-4349-bfa8-4a17e74f8404
# 4    aljazeerachannel  Facebook  9d32629d-adc1-4bb5-937e-7797a1bbe47e
# ..                ...       ...                                   ...
# 253  aljazeerachannel  Facebook  b182c81d-ab85-48fd-b728-3677d8d1e99b
# 254  aljazeerachannel  Facebook  76e04484-13c8-4cb8-a114-1b4befc0bc9e
# 255  aljazeerachannel  Facebook  52a203ef-40ca-440c-b916-da85e6775c44
# 256  aljazeerachannel  Facebook  be830853-40df-4b05-b272-883bdd578dff
# 257  aljazeerachannel  Facebook  4b621827-8143-40c8-bc0c-b3f969e9ea79
#
#                    date  likes  comments shares  views followers  country  \
# 0   2025-03-06 17:45:07    406        55     18    NaN      20 M      NaN
# 1   2025-03-06 17:39:38   5900       927     87    NaN      20 M      NaN
# 2   2025-03-06 17:40:02    151         0    NaN    NaN       NaN      NaN
# 3   2025-03-06 17:45:15    767        28     48    NaN       NaN      NaN
# 4   2025-03-06 17:52:43    317        21      3    NaN       NaN      NaN
# ..                  ...    ...       ...    ...    ...       ...      ...
# 253 2024-03-06 19:39:37   3500        33     53    NaN       NaN      NaN
# 254 2024-03-06 19:39:47    220         8      6    NaN       NaN      NaN
# 255 2024-03-06 19:39:57    230        11      6    NaN       NaN      NaN
# 256 2024-03-06 19:40:08    259        15      4    NaN       NaN      NaN
# 257 2024-03-06 19:40:19    274        63      4    NaN       NaN      NaN
#
#     content_type  sentiment_score  \
# 0          video              NaN
# 1          video              NaN
# 2          video              NaN
# 3          video              NaN
# 4          video              NaN
# ..           ...              ...
# 253        video              NaN
# 254        image              NaN
# 255        video              NaN
# 256        video              NaN
# 257        video              NaN
#
#                                              post_text  \
# 0    A Palestinian mother's shock, the moment she r...
# 1    Live on the air.. Violent clashes between the ...
# 2    #FIFA announces a unique offer in the final #F...
# 3    “With Palestinian and decorations”.. Children ...
# 4    Is there a common Qasim between Netanyahu and ...
# ..                                                 ...
# 253  مخاوف من عواقب “خطيرة وبعيدة المدى” إثر استهدا...
# 254     حرب العملات الرقمية المشفرة بين #حماس وإسرائيل
# 255  تفاعل على منصات التواصل مع كشف شركة “آبل” عن ن...
# 256  الاتحاد الدولي للنقل الجوي يتوقع عودة شركات ال...
# 257  رضا الجزائري وكتب الأرصفة.. حكاية تروي ظمأ الق...
#
#                                       post_origin_text        date_scraped  \
# 0    Al Jazeera Channel - قناة الجزيرة \nS\nd\ne\nn... 2025-03-06 18:39:07
# 1    Al Jazeera Channel - قناة الجزيرة \no\ns\nr\nS... 2025-03-06 18:39:38
# 2    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:02
# 3    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:15
# 4    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:41:43
# ..                                                 ...                 ...
# 253  Al Jazeera Channel - قناة الجزيرة \np\nd\ns\nS... 2025-03-06 19:39:37
# 254  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:47
# 255  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:57
# 256  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:40:08
# 257  Al Jazeera Channel - قناة الجزيرة \ne\nn\np\nr... 2025-03-06 19:40:19
#
#     date_difference
# 0               54m
# 1                1h
# 2                1h
# 3               55m
# 4               49m
# ..              ...
# 253              1y
# 254              1y
# 255              1y
# 256              1y
# 257              1y
#
# [258 rows x 16 columns]

# %%
df['shares'] = df['shares'].fillna(0)

df['shares'] = df['shares'].apply(parse_likes_comments_shares_views_followers)

df
# Out:
#               user_id  platform                               post_id  \
# 0    aljazeerachannel  Facebook  c83048a0-3b7e-4ac1-9dd8-35be5a6ecfab
# 1    aljazeerachannel  Facebook  69e34b53-c500-4eff-8d4a-f3c208b4b79b
# 2    aljazeerachannel  Facebook  03d3f92a-da56-4320-bd08-a64f3cf38c0e
# 3    aljazeerachannel  Facebook  6f000c7c-47eb-4349-bfa8-4a17e74f8404
# 4    aljazeerachannel  Facebook  9d32629d-adc1-4bb5-937e-7797a1bbe47e
# ..                ...       ...                                   ...
# 253  aljazeerachannel  Facebook  b182c81d-ab85-48fd-b728-3677d8d1e99b
# 254  aljazeerachannel  Facebook  76e04484-13c8-4cb8-a114-1b4befc0bc9e
# 255  aljazeerachannel  Facebook  52a203ef-40ca-440c-b916-da85e6775c44
# 256  aljazeerachannel  Facebook  be830853-40df-4b05-b272-883bdd578dff
# 257  aljazeerachannel  Facebook  4b621827-8143-40c8-bc0c-b3f969e9ea79
#
#                    date  likes  comments  shares  views followers  country  \
# 0   2025-03-06 17:45:07    406        55      18    NaN      20 M      NaN
# 1   2025-03-06 17:39:38   5900       927      87    NaN      20 M      NaN
# 2   2025-03-06 17:40:02    151         0       0    NaN       NaN      NaN
# 3   2025-03-06 17:45:15    767        28      48    NaN       NaN      NaN
# 4   2025-03-06 17:52:43    317        21       3    NaN       NaN      NaN
# ..                  ...    ...       ...     ...    ...       ...      ...
# 253 2024-03-06 19:39:37   3500        33      53    NaN       NaN      NaN
# 254 2024-03-06 19:39:47    220         8       6    NaN       NaN      NaN
# 255 2024-03-06 19:39:57    230        11       6    NaN       NaN      NaN
# 256 2024-03-06 19:40:08    259        15       4    NaN       NaN      NaN
# 257 2024-03-06 19:40:19    274        63       4    NaN       NaN      NaN
#
#     content_type  sentiment_score  \
# 0          video              NaN
# 1          video              NaN
# 2          video              NaN
# 3          video              NaN
# 4          video              NaN
# ..           ...              ...
# 253        video              NaN
# 254        image              NaN
# 255        video              NaN
# 256        video              NaN
# 257        video              NaN
#
#                                              post_text  \
# 0    A Palestinian mother's shock, the moment she r...
# 1    Live on the air.. Violent clashes between the ...
# 2    #FIFA announces a unique offer in the final #F...
# 3    “With Palestinian and decorations”.. Children ...
# 4    Is there a common Qasim between Netanyahu and ...
# ..                                                 ...
# 253  مخاوف من عواقب “خطيرة وبعيدة المدى” إثر استهدا...
# 254     حرب العملات الرقمية المشفرة بين #حماس وإسرائيل
# 255  تفاعل على منصات التواصل مع كشف شركة “آبل” عن ن...
# 256  الاتحاد الدولي للنقل الجوي يتوقع عودة شركات ال...
# 257  رضا الجزائري وكتب الأرصفة.. حكاية تروي ظمأ الق...
#
#                                       post_origin_text        date_scraped  \
# 0    Al Jazeera Channel - قناة الجزيرة \nS\nd\ne\nn... 2025-03-06 18:39:07
# 1    Al Jazeera Channel - قناة الجزيرة \no\ns\nr\nS... 2025-03-06 18:39:38
# 2    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:02
# 3    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:15
# 4    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:41:43
# ..                                                 ...                 ...
# 253  Al Jazeera Channel - قناة الجزيرة \np\nd\ns\nS... 2025-03-06 19:39:37
# 254  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:47
# 255  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:57
# 256  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:40:08
# 257  Al Jazeera Channel - قناة الجزيرة \ne\nn\np\nr... 2025-03-06 19:40:19
#
#     date_difference
# 0               54m
# 1                1h
# 2                1h
# 3               55m
# 4               49m
# ..              ...
# 253              1y
# 254              1y
# 255              1y
# 256              1y
# 257              1y
#
# [258 rows x 16 columns]

# %%
df['views'] = df['views'].fillna(0)

df['views'] = df['views'].apply(parse_likes_comments_shares_views_followers)

df
# Out:
#               user_id  platform                               post_id  \
# 0    aljazeerachannel  Facebook  c83048a0-3b7e-4ac1-9dd8-35be5a6ecfab
# 1    aljazeerachannel  Facebook  69e34b53-c500-4eff-8d4a-f3c208b4b79b
# 2    aljazeerachannel  Facebook  03d3f92a-da56-4320-bd08-a64f3cf38c0e
# 3    aljazeerachannel  Facebook  6f000c7c-47eb-4349-bfa8-4a17e74f8404
# 4    aljazeerachannel  Facebook  9d32629d-adc1-4bb5-937e-7797a1bbe47e
# ..                ...       ...                                   ...
# 253  aljazeerachannel  Facebook  b182c81d-ab85-48fd-b728-3677d8d1e99b
# 254  aljazeerachannel  Facebook  76e04484-13c8-4cb8-a114-1b4befc0bc9e
# 255  aljazeerachannel  Facebook  52a203ef-40ca-440c-b916-da85e6775c44
# 256  aljazeerachannel  Facebook  be830853-40df-4b05-b272-883bdd578dff
# 257  aljazeerachannel  Facebook  4b621827-8143-40c8-bc0c-b3f969e9ea79
#
#                    date  likes  comments  shares  views followers  country  \
# 0   2025-03-06 17:45:07    406        55      18      0      20 M      NaN
# 1   2025-03-06 17:39:38   5900       927      87      0      20 M      NaN
# 2   2025-03-06 17:40:02    151         0       0      0       NaN      NaN
# 3   2025-03-06 17:45:15    767        28      48      0       NaN      NaN
# 4   2025-03-06 17:52:43    317        21       3      0       NaN      NaN
# ..                  ...    ...       ...     ...    ...       ...      ...
# 253 2024-03-06 19:39:37   3500        33      53      0       NaN      NaN
# 254 2024-03-06 19:39:47    220         8       6      0       NaN      NaN
# 255 2024-03-06 19:39:57    230        11       6      0       NaN      NaN
# 256 2024-03-06 19:40:08    259        15       4      0       NaN      NaN
# 257 2024-03-06 19:40:19    274        63       4      0       NaN      NaN
#
#     content_type  sentiment_score  \
# 0          video              NaN
# 1          video              NaN
# 2          video              NaN
# 3          video              NaN
# 4          video              NaN
# ..           ...              ...
# 253        video              NaN
# 254        image              NaN
# 255        video              NaN
# 256        video              NaN
# 257        video              NaN
#
#                                              post_text  \
# 0    A Palestinian mother's shock, the moment she r...
# 1    Live on the air.. Violent clashes between the ...
# 2    #FIFA announces a unique offer in the final #F...
# 3    “With Palestinian and decorations”.. Children ...
# 4    Is there a common Qasim between Netanyahu and ...
# ..                                                 ...
# 253  مخاوف من عواقب “خطيرة وبعيدة المدى” إثر استهدا...
# 254     حرب العملات الرقمية المشفرة بين #حماس وإسرائيل
# 255  تفاعل على منصات التواصل مع كشف شركة “آبل” عن ن...
# 256  الاتحاد الدولي للنقل الجوي يتوقع عودة شركات ال...
# 257  رضا الجزائري وكتب الأرصفة.. حكاية تروي ظمأ الق...
#
#                                       post_origin_text        date_scraped  \
# 0    Al Jazeera Channel - قناة الجزيرة \nS\nd\ne\nn... 2025-03-06 18:39:07
# 1    Al Jazeera Channel - قناة الجزيرة \no\ns\nr\nS... 2025-03-06 18:39:38
# 2    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:02
# 3    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:15
# 4    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:41:43
# ..                                                 ...                 ...
# 253  Al Jazeera Channel - قناة الجزيرة \np\nd\ns\nS... 2025-03-06 19:39:37
# 254  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:47
# 255  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:57
# 256  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:40:08
# 257  Al Jazeera Channel - قناة الجزيرة \ne\nn\np\nr... 2025-03-06 19:40:19
#
#     date_difference
# 0               54m
# 1                1h
# 2                1h
# 3               55m
# 4               49m
# ..              ...
# 253              1y
# 254              1y
# 255              1y
# 256              1y
# 257              1y
#
# [258 rows x 16 columns]

# %%
df['followers'] = df['followers'].fillna(0)

df['followers'] = df['followers'].apply(parse_likes_comments_shares_views_followers)

df
# Out:
#               user_id  platform                               post_id  \
# 0    aljazeerachannel  Facebook  c83048a0-3b7e-4ac1-9dd8-35be5a6ecfab
# 1    aljazeerachannel  Facebook  69e34b53-c500-4eff-8d4a-f3c208b4b79b
# 2    aljazeerachannel  Facebook  03d3f92a-da56-4320-bd08-a64f3cf38c0e
# 3    aljazeerachannel  Facebook  6f000c7c-47eb-4349-bfa8-4a17e74f8404
# 4    aljazeerachannel  Facebook  9d32629d-adc1-4bb5-937e-7797a1bbe47e
# ..                ...       ...                                   ...
# 253  aljazeerachannel  Facebook  b182c81d-ab85-48fd-b728-3677d8d1e99b
# 254  aljazeerachannel  Facebook  76e04484-13c8-4cb8-a114-1b4befc0bc9e
# 255  aljazeerachannel  Facebook  52a203ef-40ca-440c-b916-da85e6775c44
# 256  aljazeerachannel  Facebook  be830853-40df-4b05-b272-883bdd578dff
# 257  aljazeerachannel  Facebook  4b621827-8143-40c8-bc0c-b3f969e9ea79
#
#                    date  likes  comments  shares  views  followers  country  \
# 0   2025-03-06 17:45:07    406        55      18      0   20000000      NaN
# 1   2025-03-06 17:39:38   5900       927      87      0   20000000      NaN
# 2   2025-03-06 17:40:02    151         0       0      0          0      NaN
# 3   2025-03-06 17:45:15    767        28      48      0          0      NaN
# 4   2025-03-06 17:52:43    317        21       3      0          0      NaN
# ..                  ...    ...       ...     ...    ...        ...      ...
# 253 2024-03-06 19:39:37   3500        33      53      0          0      NaN
# 254 2024-03-06 19:39:47    220         8       6      0          0      NaN
# 255 2024-03-06 19:39:57    230        11       6      0          0      NaN
# 256 2024-03-06 19:40:08    259        15       4      0          0      NaN
# 257 2024-03-06 19:40:19    274        63       4      0          0      NaN
#
#     content_type  sentiment_score  \
# 0          video              NaN
# 1          video              NaN
# 2          video              NaN
# 3          video              NaN
# 4          video              NaN
# ..           ...              ...
# 253        video              NaN
# 254        image              NaN
# 255        video              NaN
# 256        video              NaN
# 257        video              NaN
#
#                                              post_text  \
# 0    A Palestinian mother's shock, the moment she r...
# 1    Live on the air.. Violent clashes between the ...
# 2    #FIFA announces a unique offer in the final #F...
# 3    “With Palestinian and decorations”.. Children ...
# 4    Is there a common Qasim between Netanyahu and ...
# ..                                                 ...
# 253  مخاوف من عواقب “خطيرة وبعيدة المدى” إثر استهدا...
# 254     حرب العملات الرقمية المشفرة بين #حماس وإسرائيل
# 255  تفاعل على منصات التواصل مع كشف شركة “آبل” عن ن...
# 256  الاتحاد الدولي للنقل الجوي يتوقع عودة شركات ال...
# 257  رضا الجزائري وكتب الأرصفة.. حكاية تروي ظمأ الق...
#
#                                       post_origin_text        date_scraped  \
# 0    Al Jazeera Channel - قناة الجزيرة \nS\nd\ne\nn... 2025-03-06 18:39:07
# 1    Al Jazeera Channel - قناة الجزيرة \no\ns\nr\nS... 2025-03-06 18:39:38
# 2    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:02
# 3    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:15
# 4    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:41:43
# ..                                                 ...                 ...
# 253  Al Jazeera Channel - قناة الجزيرة \np\nd\ns\nS... 2025-03-06 19:39:37
# 254  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:47
# 255  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:57
# 256  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:40:08
# 257  Al Jazeera Channel - قناة الجزيرة \ne\nn\np\nr... 2025-03-06 19:40:19
#
#     date_difference
# 0               54m
# 1                1h
# 2                1h
# 3               55m
# 4               49m
# ..              ...
# 253              1y
# 254              1y
# 255              1y
# 256              1y
# 257              1y
#
# [258 rows x 16 columns]

# %%
df['country'] = df['country'].fillna("")
df
# Out:
#               user_id  platform                               post_id  \
# 0    aljazeerachannel  Facebook  c83048a0-3b7e-4ac1-9dd8-35be5a6ecfab
# 1    aljazeerachannel  Facebook  69e34b53-c500-4eff-8d4a-f3c208b4b79b
# 2    aljazeerachannel  Facebook  03d3f92a-da56-4320-bd08-a64f3cf38c0e
# 3    aljazeerachannel  Facebook  6f000c7c-47eb-4349-bfa8-4a17e74f8404
# 4    aljazeerachannel  Facebook  9d32629d-adc1-4bb5-937e-7797a1bbe47e
# ..                ...       ...                                   ...
# 253  aljazeerachannel  Facebook  b182c81d-ab85-48fd-b728-3677d8d1e99b
# 254  aljazeerachannel  Facebook  76e04484-13c8-4cb8-a114-1b4befc0bc9e
# 255  aljazeerachannel  Facebook  52a203ef-40ca-440c-b916-da85e6775c44
# 256  aljazeerachannel  Facebook  be830853-40df-4b05-b272-883bdd578dff
# 257  aljazeerachannel  Facebook  4b621827-8143-40c8-bc0c-b3f969e9ea79
#
#                    date  likes  comments  shares  views  followers country  \
# 0   2025-03-06 17:45:07    406        55      18      0   20000000
# 1   2025-03-06 17:39:38   5900       927      87      0   20000000
# 2   2025-03-06 17:40:02    151         0       0      0          0
# 3   2025-03-06 17:45:15    767        28      48      0          0
# 4   2025-03-06 17:52:43    317        21       3      0          0
# ..                  ...    ...       ...     ...    ...        ...     ...
# 253 2024-03-06 19:39:37   3500        33      53      0          0
# 254 2024-03-06 19:39:47    220         8       6      0          0
# 255 2024-03-06 19:39:57    230        11       6      0          0
# 256 2024-03-06 19:40:08    259        15       4      0          0
# 257 2024-03-06 19:40:19    274        63       4      0          0
#
#     content_type  sentiment_score  \
# 0          video              NaN
# 1          video              NaN
# 2          video              NaN
# 3          video              NaN
# 4          video              NaN
# ..           ...              ...
# 253        video              NaN
# 254        image              NaN
# 255        video              NaN
# 256        video              NaN
# 257        video              NaN
#
#                                              post_text  \
# 0    A Palestinian mother's shock, the moment she r...
# 1    Live on the air.. Violent clashes between the ...
# 2    #FIFA announces a unique offer in the final #F...
# 3    “With Palestinian and decorations”.. Children ...
# 4    Is there a common Qasim between Netanyahu and ...
# ..                                                 ...
# 253  مخاوف من عواقب “خطيرة وبعيدة المدى” إثر استهدا...
# 254     حرب العملات الرقمية المشفرة بين #حماس وإسرائيل
# 255  تفاعل على منصات التواصل مع كشف شركة “آبل” عن ن...
# 256  الاتحاد الدولي للنقل الجوي يتوقع عودة شركات ال...
# 257  رضا الجزائري وكتب الأرصفة.. حكاية تروي ظمأ الق...
#
#                                       post_origin_text        date_scraped  \
# 0    Al Jazeera Channel - قناة الجزيرة \nS\nd\ne\nn... 2025-03-06 18:39:07
# 1    Al Jazeera Channel - قناة الجزيرة \no\ns\nr\nS... 2025-03-06 18:39:38
# 2    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:02
# 3    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:40:15
# 4    Al Jazeera Channel - قناة الجزيرة \nr\nn\ns\ne... 2025-03-06 18:41:43
# ..                                                 ...                 ...
# 253  Al Jazeera Channel - قناة الجزيرة \np\nd\ns\nS... 2025-03-06 19:39:37
# 254  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:47
# 255  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:39:57
# 256  Al Jazeera Channel - قناة الجزيرة \nn\np\ne\no... 2025-03-06 19:40:08
# 257  Al Jazeera Channel - قناة الجزيرة \ne\nn\np\nr... 2025-03-06 19:40:19
#
#     date_difference
# 0               54m
# 1                1h
# 2                1h
# 3               55m
# 4               49m
# ..              ...
# 253              1y
# 254              1y
# 255              1y
# 256              1y
# 257              1y
#
# [258 rows x 16 columns]

# %%
df_post_youtube = pd.read_excel('../Scraping_Output/youtube_data.xlsx')
df_post_youtube
# Out:
#              user_id  platform                               post_id  \
# 0   aljazeerachannel  Facebook  27c8d322-f361-48cc-bf5b-a886062806f0
# 1          aljazeera   Youtube  c675acab-962e-4baa-ae5e-93f435b9c11f
# 2          aljazeera   Youtube  ac9a0faf-21c0-434b-9a04-51ee76f389c2
# 3          aljazeera   Youtube  b7664017-dd3f-4a36-89cd-8314b40341f0
# 4          aljazeera   Youtube  6eb73b86-3a30-4178-a752-ce73b761a568
# 5          aljazeera   Youtube  f8aa20c0-009f-4e1a-ac68-b452ac8e6c02
# 6          aljazeera   Youtube  b9784d68-ecac-4573-abcb-90b597722957
# 7          aljazeera   Youtube  8e605043-4890-4946-add3-7f0b5493b85d
# 8          aljazeera   Youtube  fa242f96-ac87-46c7-bfbb-602e72b74f16
# 9          aljazeera   Youtube  76988744-a554-43b3-b4be-6c2a3dbae65b
# 10         aljazeera   Youtube  ff26d731-35bf-4f62-83ee-be2d75a50e0d
#
#             date likes  comments  shares  \
# 0            NaN   356        64    12.0
# 1     1 hour ago   591        26     NaN
# 2     1 hour ago  2.3K       138     NaN
# 3    3 hours ago   531        40     NaN
# 4    5 hours ago  6.7K       125     NaN
# 5    6 hours ago   994        42     NaN
# 6    7 hours ago   318        65     NaN
# 7    7 hours ago   986       109     NaN
# 8    8 hours ago   912        57     NaN
# 9    9 hours ago   524        59     NaN
# 10  10 hours ago   322        56     NaN
#
#                                             post_text  \
# 0   Breaking | Reuters on diplomats: #Washington a...
# 1   رئيس البرلمان الإيراني: تصرفات ترمب مع الدول ا...
# 2   #عاجل | الرئيس السوري: المخاطر التي نواجهها هي...
# 3   #إيلون_ماسك: نظام ستارلينك هو العمود الفقري لل...
# 4   #حماس: وافقنا على تشكيل لجنة من شخصيات وطنية م...
# 5   #عاجل | مصادر للجزيرة: دبابات الاحتلال تقتحم م...
# 6   نتنياهو يشكر #ترمب على دعمه "الجريء" لإسرائيل ...
# 7   #عاجل | مصدر أمني للجزيرة: الانتهاء من تمشيط ب...
# 8   #حدث_في_رمضان | على مقربة من سهل بطليوس بإسبان...
# 9   خامنئي ردا على دعوة #ترمب للتفاوض: إصرار بعض ا...
# 10  #عاجل | بن غفير: تقدمت بمقترح قانون لإلغاء اتف...
#
#                                      post_origin_text         date_scraped  \
# 0   Al Jazeera Channel - قناة الجزيرة\n n\nd\no\ne...  2025-03-09 22:18:20
# 1   AlJazeera Arabic قناة الجزيرة\n1 hour ago\nرئي...  2025-03-09 22:18:45
# 2   AlJazeera Arabic قناة الجزيرة\n1 hour ago\n#عا...  2025-03-09 22:18:50
# 3   AlJazeera Arabic قناة الجزيرة\n3 hours ago\n#إ...  2025-03-09 22:18:55
# 4   AlJazeera Arabic قناة الجزيرة\n5 hours ago\n#ح...  2025-03-09 22:19:00
# 5   AlJazeera Arabic قناة الجزيرة\n6 hours ago\n#ع...  2025-03-09 22:19:05
# 6   AlJazeera Arabic قناة الجزيرة\n7 hours ago\nنت...  2025-03-09 22:19:11
# 7   AlJazeera Arabic قناة الجزيرة\n7 hours ago\n#ع...  2025-03-09 22:19:17
# 8   AlJazeera Arabic قناة الجزيرة\n8 hours ago\n#ح...  2025-03-09 22:19:22
# 9   AlJazeera Arabic قناة الجزيرة\n9 hours ago\nخا...  2025-03-09 22:19:28
# 10  AlJazeera Arabic قناة الجزيرة\n10 hours ago\n#...  2025-03-09 22:19:33
#
#     views          followers  country content_type  sentiment_score
# 0     NaN      30M followers      NaN        image              NaN
# 1     NaN  19.9M subscribers      NaN        image              NaN
# 2     NaN  19.9M subscribers      NaN        image              NaN
# 3     NaN  19.9M subscribers      NaN        image              NaN
# 4     NaN  19.9M subscribers      NaN        image              NaN
# 5     NaN  19.9M subscribers      NaN        image              NaN
# 6     NaN  19.9M subscribers      NaN        image              NaN
# 7     NaN  19.9M subscribers      NaN        image              NaN
# 8     NaN  19.9M subscribers      NaN        image              NaN
# 9     NaN  19.9M subscribers      NaN        image              NaN
# 10    NaN  19.9M subscribers      NaN        image              NaN

# %%
    # Function to calculate post date
    def get_youtube_post_date(relative_time, scrape_date):
        match = re.match(r"(\d+) (minute|hour|day|year)s? ago", relative_time)
        if match:
            value, unit = int(match.group(1)), match.group(2)
            if unit == "minute":
                return scrape_date - timedelta(minutes=value)
            elif unit == "hour":
                return scrape_date - timedelta(hours=value)
            elif unit == "day":
                return scrape_date - timedelta(days=value)
            elif unit == "year":
                return scrape_date.replace(year=scrape_date.year - value)
        elif "edited" in relative_time:
            return get_post_date(relative_time.replace(" (edited)", ""))
        return None

# %%
        # Remove rows where 'post_origin_text' is empty (i.e., NaN)
        df_post_youtube = df_post_youtube.dropna(subset=['post_origin_text'])

        # Reset the index of the DataFrame after dropping rows, without keeping the old index
        df_post_youtube = df_post_youtube.reset_index(drop=True)
                
        # Convert the 'date_scraped' column to datetime format
        df_post_youtube['date_scraped'] = pd.to_datetime(df_post_youtube['date_scraped'])
        
        # Apply a custom function to calculate 'date' based on 'date_scraped' for each row
        df_post_youtube['date'] = df_post_youtube.apply(lambda row: get_youtube_post_date(row['date'], row['date_scraped']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[187], line 11
#       8 df_post_youtube['date_scraped'] = pd.to_datetime(df_post_youtube['date_scraped'])
#      10 # Apply a custom function to calculate 'date' based on 'date_scraped' for each row
# ---> 11 df_post_youtube['date'] = df_post_youtube.apply(lambda row: get_youtube_post_date(row['date'], row['date_scraped']), axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[187], line 11, in <lambda>(row)
#       8 df_post_youtube['date_scraped'] = pd.to_datetime(df_post_youtube['date_scraped'])
#      10 # Apply a custom function to calculate 'date' based on 'date_scraped' for each row
# ---> 11 df_post_youtube['date'] = df_post_youtube.apply(lambda row: get_youtube_post_date(row['date'], row['date_scraped']), axis=1)
#
# Cell In[186], line 3, in get_youtube_post_date(relative_time, scrape_date)
#       2 def get_youtube_post_date(relative_time, scrape_date):
# ----> 3     match = re.match(r"(\d+) (minute|hour|day|year)s? ago", relative_time)
#       4     if match:
#       5         value, unit = int(match.group(1)), match.group(2)
#
# File ~\anaconda3\Lib\re\__init__.py:166, in match(pattern, string, flags)
#     163 def match(pattern, string, flags=0):
#     164     """Try to apply the pattern at the start of the string, returning
#     165     a Match object, or None if no match was found."""
# --> 166     return _compile(pattern, flags).match(string)
#
# TypeError: expected string or bytes-like object, got 'float'
